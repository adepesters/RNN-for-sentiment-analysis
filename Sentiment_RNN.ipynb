# %% [markdown]
# # Sentiment Analysis Using RNN
# - [Introduction](#intro)
# - [Part 1: Data Preprocessing](#part1)
# - [Part 2: RNN Building](#part2)
# - [Part 3: RNN Training and Testing](#part3)

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# In this project, I'll build and train an RNN using Tensorflow to recognize between positive and negative movie reviews from the Internet Movie Database (IMDB).
#
# The notebook consists of 4 parts: in Part 1 I'll preprocess the data. In Part 2, I'll build the network, which will then be trained and tested in Part 3. An accuracy of ~84% is achieved.

# %%
import numpy as np
import tensorflow as tf
from collections import Counter
from string import punctuation

# %% [markdown]
# <a id='part1'></a>
# ## Part 1: Data Preprocessing
#
# First, a bit of preprocessing, e.g., removing punctuation, attributing each word/label to an integer code, getting rid of potential empty reviews, and adjusting the review size to a fixed length.

# %%
with open('reviews.txt', 'r') as f:
    reviews = f.read()
with open('labels.txt', 'r') as f:
    labels = f.read()

# Remove punctuation
all_text = ''.join([c for c in reviews if c not in punctuation])

# Split reviews using delimiter \n
reviews = all_text.split('\n')

# Extract individual words
all_text = ' '.join(reviews)
words = all_text.split()

# Create dictionary that maps each word to an integer
tmp = Counter(words)
tmp_sorted = sorted(tmp, key=tmp.get, reverse=True)
vocab_to_int = {word: num for num, word in enumerate(tmp_sorted)}

# Convert the reviews to lists of integers using the vocab_to_int code
reviews_ints = []
for review in reviews:
    reviews_ints.append([vocab_to_int[word] for word in review.split()])
    
# Convert labels to 1s and 0s for 'positive' and 'negative'
labels = labels.split('\n')
labels = np.array([1 if label == 'positive' else 0 for label in labels])

# Filter out any empty review
non_zero_idx = [idx for idx, review in enumerate(reviews_ints) if len(review) != 0]
reviews_ints = [reviews_ints[idx] for idx in non_zero_idx]
labels = np.array([labels[idx] for idx in non_zero_idx])

# Truncate reviews to <seq_len> words, and pad shorter reviews with 0s
seq_len = 200
features = np.zeros((len(reviews_ints), seq_len), dtype=int)
for i, row in enumerate(reviews_ints):
    features[i, -len(row):] = np.array(row)[:seq_len]
    
# Split data between training (80%), validation (10%), and test (10%) sets
split_frac = 0.8
split_idx = int(len(features)*0.8)
train_x, val_x = features[:split_idx], features[split_idx:]
train_y, val_y = labels[:split_idx], labels[split_idx:]

test_idx = int(len(val_x)*0.5)
val_x, test_x = val_x[:test_idx], val_x[test_idx:]
val_y, test_y = val_y[:test_idx], val_y[test_idx:]

# %% [markdown]
# <a id='part2'></a>
# ## Part 2: RNN Building
#
# Let's then build the RNN. Here, we will use an embedding layer for our words, LSTM cells, and some dropout.

# %%
lstm_size = 256 # Number of units in LSTM cell
lstm_layers = 1
batch_size = 500
learning_rate = 0.001

n_words = len(vocab_to_int)

tf.reset_default_graph()

# Define placeholders for inputs and labels
inputs_ = tf.placeholder(tf.int32, [None, None], name='inputs') # size: batch_size*length of review
labels_ = tf.placeholder(tf.int32, [None, None], name='labels')

# Define dropout probability
keep_prob = tf.placeholder(tf.float32, name='keep_prob')

# Define the embedding layer
embed_size = 300 # Size of the embedding vectors (number of units in the embedding layer)
# Initialize embedding layer with random values between -1 and 1
embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
embed = tf.nn.embedding_lookup(embedding, inputs_)
    
# Build LSTM cell
def build_cell(lstm_size, keep_prob):
    
    # Define LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    
    # Add dropout to the cell
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob = keep_prob)
    return drop
    
# Stack up multiple LSTM layers
cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range (lstm_layers)])
    
# Set initial state to 0s
initial_state = cell.zero_state(batch_size, tf.float32)
    
# Pass embedded data through RNN
outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)
    
# Get last output of RNN
predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)

# Define cost
cost = tf.losses.mean_squared_error(labels_, predictions)
    
# Define optimizer
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    
# Define accuracy
correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# <a id='part3'></a>
# ## Part 3: RNN Training and Testing
#
# Finally, let's train and test the model:

# %%
epochs = 20

# Define batches
def get_batches(x, y, batch_size):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 0.5,
                    initial_state: state}
            loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)
            
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))
                
            iteration +=1
                
        # Print accuracy for current epoch
        val_acc = []
        # Necessary to initialize cell state with 0s
        val_state = sess.run(cell.zero_state(batch_size, tf.float32))
        for x, y in get_batches(val_x, val_y, batch_size):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 1,
                    initial_state: val_state}
            batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
            val_acc.append(batch_acc)
        print("Val acc: {:.3f}".format(np.mean(val_acc)))

    saver.save(sess, "checkpoints/sentiment.ckpt")
# Out:
# Epoch: 0/20 Iteration: 5 Train loss: 0.243
# Epoch: 0/20 Iteration: 10 Train loss: 0.244
# Epoch: 0/20 Iteration: 15 Train loss: 0.210
# Epoch: 0/20 Iteration: 20 Train loss: 0.223
# Epoch: 0/20 Iteration: 25 Train loss: 0.229
# Epoch: 0/20 Iteration: 30 Train loss: 0.223
# Epoch: 0/20 Iteration: 35 Train loss: 0.206
# Epoch: 0/20 Iteration: 40 Train loss: 0.182
# Val acc: 0.726
# Epoch: 1/20 Iteration: 45 Train loss: 0.184
# Epoch: 1/20 Iteration: 50 Train loss: 0.193
# Epoch: 1/20 Iteration: 55 Train loss: 0.177
# Epoch: 1/20 Iteration: 60 Train loss: 0.182
# Epoch: 1/20 Iteration: 65 Train loss: 0.224
# Epoch: 1/20 Iteration: 70 Train loss: 0.210
# Epoch: 1/20 Iteration: 75 Train loss: 0.209
# Epoch: 1/20 Iteration: 80 Train loss: 0.218
# Val acc: 0.658
# Epoch: 2/20 Iteration: 85 Train loss: 0.178
# Epoch: 2/20 Iteration: 90 Train loss: 0.172
# Epoch: 2/20 Iteration: 95 Train loss: 0.147
# Epoch: 2/20 Iteration: 100 Train loss: 0.137
# Epoch: 2/20 Iteration: 105 Train loss: 0.143
# Epoch: 2/20 Iteration: 110 Train loss: 0.161
# Epoch: 2/20 Iteration: 115 Train loss: 0.153
# Epoch: 2/20 Iteration: 120 Train loss: 0.157
# Val acc: 0.753
# Epoch: 3/20 Iteration: 125 Train loss: 0.105
# Epoch: 3/20 Iteration: 130 Train loss: 0.116
# Epoch: 3/20 Iteration: 135 Train loss: 0.107
# Epoch: 3/20 Iteration: 140 Train loss: 0.105
# Epoch: 3/20 Iteration: 145 Train loss: 0.223
# Epoch: 3/20 Iteration: 150 Train loss: 0.150
# Epoch: 3/20 Iteration: 155 Train loss: 0.136
# Epoch: 3/20 Iteration: 160 Train loss: 0.130
# Val acc: 0.788
# Epoch: 4/20 Iteration: 165 Train loss: 0.097
# Epoch: 4/20 Iteration: 170 Train loss: 0.108
# Epoch: 4/20 Iteration: 175 Train loss: 0.091
# Epoch: 4/20 Iteration: 180 Train loss: 0.064
# Epoch: 4/20 Iteration: 185 Train loss: 0.065
# Epoch: 4/20 Iteration: 190 Train loss: 0.103
# Epoch: 4/20 Iteration: 195 Train loss: 0.124
# Epoch: 4/20 Iteration: 200 Train loss: 0.130
# Val acc: 0.758
# Epoch: 5/20 Iteration: 205 Train loss: 0.119
# Epoch: 5/20 Iteration: 210 Train loss: 0.080
# Epoch: 5/20 Iteration: 215 Train loss: 0.053
# Epoch: 5/20 Iteration: 220 Train loss: 0.106
# Epoch: 5/20 Iteration: 225 Train loss: 0.132
# Epoch: 5/20 Iteration: 230 Train loss: 0.073
# Epoch: 5/20 Iteration: 235 Train loss: 0.094
# Epoch: 5/20 Iteration: 240 Train loss: 0.136
# Val acc: 0.777
# Epoch: 6/20 Iteration: 245 Train loss: 0.083
# Epoch: 6/20 Iteration: 250 Train loss: 0.188
# Epoch: 6/20 Iteration: 255 Train loss: 0.110
# Epoch: 6/20 Iteration: 260 Train loss: 0.097
# Epoch: 6/20 Iteration: 265 Train loss: 0.060
# Epoch: 6/20 Iteration: 270 Train loss: 0.098
# Epoch: 6/20 Iteration: 275 Train loss: 0.067
# Epoch: 6/20 Iteration: 280 Train loss: 0.076
# Val acc: 0.805
# Epoch: 7/20 Iteration: 285 Train loss: 0.055
# Epoch: 7/20 Iteration: 290 Train loss: 0.080
# Epoch: 7/20 Iteration: 295 Train loss: 0.192
# Epoch: 7/20 Iteration: 300 Train loss: 0.124
# Epoch: 7/20 Iteration: 305 Train loss: 0.120
# Epoch: 7/20 Iteration: 310 Train loss: 0.137
# Epoch: 7/20 Iteration: 315 Train loss: 0.064
# Epoch: 7/20 Iteration: 320 Train loss: 0.056
# Val acc: 0.802
# Epoch: 8/20 Iteration: 325 Train loss: 0.042
# Epoch: 8/20 Iteration: 330 Train loss: 0.138
# Epoch: 8/20 Iteration: 335 Train loss: 0.156
# Epoch: 8/20 Iteration: 340 Train loss: 0.145
# Epoch: 8/20 Iteration: 345 Train loss: 0.132
# Epoch: 8/20 Iteration: 350 Train loss: 0.112
# Epoch: 8/20 Iteration: 355 Train loss: 0.075
# Epoch: 8/20 Iteration: 360 Train loss: 0.114
# Val acc: 0.804
# Epoch: 9/20 Iteration: 365 Train loss: 0.056
# Epoch: 9/20 Iteration: 370 Train loss: 0.061
# Epoch: 9/20 Iteration: 375 Train loss: 0.051
# Epoch: 9/20 Iteration: 380 Train loss: 0.048
# Epoch: 9/20 Iteration: 385 Train loss: 0.021
# Epoch: 9/20 Iteration: 390 Train loss: 0.028
# Epoch: 9/20 Iteration: 395 Train loss: 0.028
# Epoch: 9/20 Iteration: 400 Train loss: 0.025
# Val acc: 0.718
# Epoch: 10/20 Iteration: 405 Train loss: 0.124
# Epoch: 10/20 Iteration: 410 Train loss: 0.060
# Epoch: 10/20 Iteration: 415 Train loss: 0.081
# Epoch: 10/20 Iteration: 420 Train loss: 0.093
# Epoch: 10/20 Iteration: 425 Train loss: 0.087
# Epoch: 10/20 Iteration: 430 Train loss: 0.048
# Epoch: 10/20 Iteration: 435 Train loss: 0.027
# Epoch: 10/20 Iteration: 440 Train loss: 0.025
# Val acc: 0.776
# Epoch: 11/20 Iteration: 445 Train loss: 0.111
# Epoch: 11/20 Iteration: 450 Train loss: 0.125
# Epoch: 11/20 Iteration: 455 Train loss: 0.095
# Epoch: 11/20 Iteration: 460 Train loss: 0.064
# Epoch: 11/20 Iteration: 465 Train loss: 0.061
# Epoch: 11/20 Iteration: 470 Train loss: 0.035
# Epoch: 11/20 Iteration: 475 Train loss: 0.049
# Epoch: 11/20 Iteration: 480 Train loss: 0.055
# Val acc: 0.674
# Epoch: 12/20 Iteration: 485 Train loss: 0.116
# Epoch: 12/20 Iteration: 490 Train loss: 0.083
# Epoch: 12/20 Iteration: 495 Train loss: 0.107
# Epoch: 12/20 Iteration: 500 Train loss: 0.095
# Epoch: 12/20 Iteration: 505 Train loss: 0.076
# Epoch: 12/20 Iteration: 510 Train loss: 0.066
# Epoch: 12/20 Iteration: 515 Train loss: 0.038
# Epoch: 12/20 Iteration: 520 Train loss: 0.031
# Val acc: 0.778
# Epoch: 13/20 Iteration: 525 Train loss: 0.055
# Epoch: 13/20 Iteration: 530 Train loss: 0.071
# Epoch: 13/20 Iteration: 535 Train loss: 0.055
# Epoch: 13/20 Iteration: 540 Train loss: 0.061
# Epoch: 13/20 Iteration: 545 Train loss: 0.044
# Epoch: 13/20 Iteration: 550 Train loss: 0.039
# Epoch: 13/20 Iteration: 555 Train loss: 0.064
# Epoch: 13/20 Iteration: 560 Train loss: 0.052
# Val acc: 0.687
# Epoch: 14/20 Iteration: 565 Train loss: 0.161
# Epoch: 14/20 Iteration: 570 Train loss: 0.087
# Epoch: 14/20 Iteration: 575 Train loss: 0.084
# Epoch: 14/20 Iteration: 580 Train loss: 0.142
# Epoch: 14/20 Iteration: 585 Train loss: 0.132
# Epoch: 14/20 Iteration: 590 Train loss: 0.126
# Epoch: 14/20 Iteration: 595 Train loss: 0.093
# Epoch: 14/20 Iteration: 600 Train loss: 0.100
# Val acc: 0.769
# Epoch: 15/20 Iteration: 605 Train loss: 0.059
# Epoch: 15/20 Iteration: 610 Train loss: 0.123
# Epoch: 15/20 Iteration: 615 Train loss: 0.087
# Epoch: 15/20 Iteration: 620 Train loss: 0.099
# Epoch: 15/20 Iteration: 625 Train loss: 0.078
# Epoch: 15/20 Iteration: 630 Train loss: 0.087
# Epoch: 15/20 Iteration: 635 Train loss: 0.060
# Epoch: 15/20 Iteration: 640 Train loss: 0.075
# Val acc: 0.771
# Epoch: 16/20 Iteration: 645 Train loss: 0.039
# Epoch: 16/20 Iteration: 650 Train loss: 0.073
# Epoch: 16/20 Iteration: 655 Train loss: 0.127
# Epoch: 16/20 Iteration: 660 Train loss: 0.044
# Epoch: 16/20 Iteration: 665 Train loss: 0.074
# Epoch: 16/20 Iteration: 670 Train loss: 0.056
# Epoch: 16/20 Iteration: 675 Train loss: 0.056
# Epoch: 16/20 Iteration: 680 Train loss: 0.081
# Val acc: 0.768
# Epoch: 17/20 Iteration: 685 Train loss: 0.041
# Epoch: 17/20 Iteration: 690 Train loss: 0.046
# Epoch: 17/20 Iteration: 695 Train loss: 0.029
# Epoch: 17/20 Iteration: 700 Train loss: 0.078
# Epoch: 17/20 Iteration: 705 Train loss: 0.060
# Epoch: 17/20 Iteration: 710 Train loss: 0.046
# Epoch: 17/20 Iteration: 715 Train loss: 0.043
# Epoch: 17/20 Iteration: 720 Train loss: 0.034
# Val acc: 0.809
# Epoch: 18/20 Iteration: 725 Train loss: 0.040
# Epoch: 18/20 Iteration: 730 Train loss: 0.052
# Epoch: 18/20 Iteration: 735 Train loss: 0.038
# Epoch: 18/20 Iteration: 740 Train loss: 0.040
# Epoch: 18/20 Iteration: 745 Train loss: 0.034
# Epoch: 18/20 Iteration: 750 Train loss: 0.040
# Epoch: 18/20 Iteration: 755 Train loss: 0.026
# Epoch: 18/20 Iteration: 760 Train loss: 0.029
# Val acc: 0.825
# Epoch: 19/20 Iteration: 765 Train loss: 0.035
# Epoch: 19/20 Iteration: 770 Train loss: 0.050
# Epoch: 19/20 Iteration: 775 Train loss: 0.097
# Epoch: 19/20 Iteration: 780 Train loss: 0.082
# Epoch: 19/20 Iteration: 785 Train loss: 0.066
# Epoch: 19/20 Iteration: 790 Train loss: 0.050
# Epoch: 19/20 Iteration: 795 Train loss: 0.031
# Epoch: 19/20 Iteration: 800 Train loss: 0.028
# Val acc: 0.842

# %% [markdown]
# Testing the model:

# %%
test_acc = []
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/sentiment.ckpt
# Test accuracy: 0.839
